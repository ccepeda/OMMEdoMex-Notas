# %% [markdown]
# # Arte de las matemáticas (Carol Baur 2018-2019)
#
# ### Ejercicios y Tarea 04/12/2018
#
# #### Suma de secuencias aritméticas:  En los siguientes ejercicios debes calcular sumas de secuencias aritméticas.  Recuerda la fórmula de Gauss...
#
# #### <center> $\displaystyle\sum_{i=1}^{n} = 1 + 2 + ... + n = \frac{n(n+1)}{2}$ </center>
#
# #### Para cada pregunta debes escribir lo siguiente:
# + Variación de la secuencia de un número al siguiente.
# + Cantidad de términos en la secuencia.
# + Fórmula para calcular la suma de los primeros $n$ términos de la secuencia (utilizando como base la fórmula de Gauss).
# + Resultado de la suma planteada.
#
# ##### 1. $1 + 2 + ... + 10000 = $
#
# ##### 2. $2 + 4 + 6 + ... + 386 = $
#
# ##### 3. $12 + 14 + 16 + ... + 478 = $
#
# ##### 4. $1 + 3 + 5 + ... + 785 = $
#
# ##### 5. $23 + 25 + 27 + ... + 441 = $
#
# ##### 6. $2 + 8 + 14 + ... + 602 = $
#
# ##### 7. $(-12) + (-10) + (-8) + ... + 566 = $
#
# ##### 8. $15 + 25 + 35 + ... + 385 = $
#
# ##### 9. $7 + 21 + 35 + ... + 287 = $
#
# ##### 10. $(-98) + (-95) + (-92) + ... + 97 = $
#
# ##### 11. $683 + 679 + 675 + ... + 283 = $
#
# ##### 12. $780 + 773 + 766 + ... + (-60) = $
#
#
# #### Diferencias de cuadrados: Una de las identidades más comunes del álgebra es la de la diferencia de cuadrados, esto es $a^2 - b^2 = (a + b)(a - b)$.  Esta identidad es cierta para cualquier número, no tiene que ser forzosamente un entero.  Utiliza la identidad para resolver los siguientes ejercicios, en cada pregunta debes escribir:
#
# + Planteamiento como diferencia de cuadrados.
# + Resultado numérico de lo que se pide.
#
# ##### 13. $50^2 - 49^2 = $
#
# ##### 14. $102^2 - 100^2 = $
#
# ##### 15. $2018^2 - 2017^2 = $
#
# ##### 16. $11^2 - 9^2 = $
#
# ##### 17. $53 \times 47 = $ Pista, piensa en $53 = (50 + 3)$
#
# ##### 18. $105 \times 95 = $
#
# ##### 19. $37 \times 23 = $
#
# ##### 20. $165 \times 135 = $
#
#
# #### Cuadrados de números terminados en 5.  Si escribes un número terminado en 5 en notación semi desarrollada hasta las decenas el número puede escribirse como $10a + 5$.   Si elevas al cuadrado este número tienes lo siguiente:
#
# #### <center> $(10a + 5)^2 = 100a^2 + 100a + 25 = 100a(a + 1) + 25 = 100(a(a+1)) + 25 $</center>
#
# #### De lo anterior se observa que si se desea elevar al cuadrado un número terminado en 5 basta con tomar el total de decenas multiplicarlo por el número siguiente y agregar un 25 al final.  Es decir $35^2 = 3 \times 4 \times 100 + 25 = 1200 + 25 = 1225$
#
# #### Utiliza esa propiedad para calcular de forma sencilla los siguientes cuadrados:
#
# ##### 21. $15^2 = $
#
# ##### 22. $75^2 = $
#
# ##### 23. $95^2 = $
#
# ##### 24. $105^2 = $
#
# ##### 25. $325^2 = $
#
# #### Combina la diferencia de cuadrados con el cuadrado de números terminados en 5 para calcular rápido la multiplicación de los siguientes números.  Para cada ejercicio debes escribir:
#
# + Planteamiento como una diferencia de cuadrados que utilice el cuadrado de un número terminado en 5.
# + Respuesta.
#
# ##### 26. $44 \times 46 = $
#
# ##### 27. $64 \times 66 = $
#
# ##### 28. $83 \times 87 = $
#
# ##### 29. $92 \times 98 = $
#
# ##### 30. $120 \times 130 = $
